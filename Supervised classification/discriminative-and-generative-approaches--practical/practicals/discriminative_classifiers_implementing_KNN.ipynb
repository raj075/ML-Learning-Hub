# %% [markdown]
# # Discriminative Classifiers: K-Nearest Neighbours
#
# In this practical, we will first manually implement k-nearest neighbours. We will explore how the algorithm constructs decision boundaries and how it classifies data. We will visualise these boundaries for our own implementation, before using `sklearn` implentations to compare and contrast with our own.
#
# Then, we will move to using `sklearn` for a more traditional data science task, using a real dataset.

# %% [markdown]
# # Implementing KNN
#
# Recall that the KNN algorithm relies on the concept of distance between two items in order to quantify how similar they are. Input data is represented as an array of features, which locates each item within a vector space. We will use data with two dimensions, longitude and latitude, which will make it easy to visualise.
#
# We will need four functions:
#
# 1. `euclidean_distance(p1, p2)` - given a pair of (x,y) coordinates, calculate how close they are using Euclidean distance: $$ \sqrt{(x_2-x_1)^2+(y_2-y_1)^2} $$
# 2. `manhattan_distance(p1, p2)` - calculate $$ | x_1 - x_2 | + | y_1 - y_2 | $$
# 3. `get_neighbours(new_point, known_points, distance_function)` - given a single coordinate, calculate how close it is to all other points using the provided distance function
# 4. `classify(neighbours_list, k)` - given a list of points with their distances and their class label, determine which class is most common in the `k` nearest neighbours
#
# The classification process will work as follows:
#
# 1. For a new point with no class label, get the distance from it to every known point
# 2. From that list of distances, take the `k` nearest ones
# 3. From that subset, find out which class is the most common and use it to label the new point
#
# Below are templates for the functions, which you will complete.

# %% [markdown]
# ## The distance functions
#
# Complete the two functions below using the docstring as a guide.
#
# (Note: to calculate the absolute value for Manhattan distance, use the `abs()` function.)

# %%
from math import sqrt  # For calculating square root


def euclidean_distance(point1, point2):
    """
    Inputs:
        point1 : a tuple of (lon, lat) coordinates
        point2 : a tuple of (lon, lat) coordinates

    Returns:
        distance : a float, the distance between the points
    """

    # Your code here...
    distance=sqrt((point1[0]-point2[0])**2+(point1[1]-point2[1])**2)
    return distance

# %%
def manhattan_distance(point1, point2):
    """
    Inputs:
        point1 : a tuple of (lon, lat) coordinates
        point2 : a tuple of (lon, lat) coordinates

    Returns:
        distance : a float, the distance between the points
    """

    # Your code here...
    distance=abs(point1[0]-point2[0])+abs(point1[1]-point2[1])
    return distance

# %% [markdown]
# ## Testing the `distance` functions
#
# Run the cell below to test your functions are working as expected.

# %%
assert euclidean_distance((0, 0), (0, 0)) == 0
assert euclidean_distance((0, 0), (-1, 0)) == 1
assert euclidean_distance((0, 0), (2, 0)) == 2
assert euclidean_distance((0, 0), (1, 1)) == 1.4142135623730951
assert euclidean_distance((1233, 376.4), (-213.2, 0.03)) == 1494.372382272906

assert manhattan_distance((0, 0), (0, 0)) == 0
assert manhattan_distance((0, 0), (-1, 0)) == 1
assert manhattan_distance((0, 0), (2, 0)) == 2
assert manhattan_distance((0, 0), (1, 1)) == 2
assert manhattan_distance((1233, 376.4), (-213.2, 0.03)) == 1822.5700000000002

print("All good!")
# Out:
# All good!

# %% [markdown]
# ## The `get_neighbours` function
#
# This should loop through a list of labeled points and calculate the distance between each one and a new unlabeled point, using your `distance` function.
#
# (Note: the returned list should be sorted, such that the first item is the nearest and so on. Use `sorted()` on a list. To sort them by the third item in each sub-item, use `sorted(your_list, key=itemgetter(2))` - remember that Python starts counting at 0, not 1.)

# %%
from operator import (
    itemgetter,
)  # For sorting lists by particular items inside sub-items



def get_neighbours(new_point, known_points, distance_function):
    """
    Inputs:
        new_point : a tuple of (lon, lat) coordinates
        known_points : a list of tuples of (lon, lat, label)
        distance_function : a function to calculate distance
    Returns:
        neighbours : a sorted list of tuples with ((lon, lat), label, distance)
    """

    # Your code here...
    neighbours = []

    for lon, lat, label in known_points:
        d = distance_function(new_point, (lon, lat))

        neighbours.append(((lon, lat), label, d))


    neighbours = sorted(neighbours, key=itemgetter(2))

    return neighbours

# %% [markdown]
# ## Testing the `distance` function
#
# Run the cell below to test your function is working as expected.

# %%
known = [(0, 0, "A"), (1, 1, "A"), (3, 4, "B"), (5, 4, "B"), (1.5, 1.5, "C")]
new = (2, 2)

assert get_neighbours(new, known, euclidean_distance) == [
    ((1.5, 1.5), "C", 0.7071067811865476),
    ((1, 1), "A", 1.4142135623730951),
    ((3, 4), "B", 2.23606797749979),
    ((0, 0), "A", 2.8284271247461903),
    ((5, 4), "B", 3.605551275463989),
]

assert get_neighbours(new, known, manhattan_distance) == [
    ((1.5, 1.5), "C", 1.0),
    ((1, 1), "A", 2),
    ((3, 4), "B", 3),
    ((0, 0), "A", 4),
    ((5, 4), "B", 5),
]

print("All good!")
# Out:
# All good!

# %% [markdown]
# ## The `classify` function
#
# This function should take the output of `get_neighbours` and calculate which class is the most common in the nearest `k` items.
#
# `collections.Counter` can turn a list of items into a dictionary of item:count.
#
# `Counter(['A', 'B', 'B'])` gives you `{'A':1, 'B':2}`
#
# To get the top item, use the `.most_common()` method, which returns a sorted list of item/count pairs. The first item is the most common item.

# %%
from collections import Counter

some_list = list("AUHSUGQWURBUQWVYFVQFQFQIHIUQBF")

counts = Counter(some_list)
print(f"The counter: {counts}\n")

top_item = counts.most_common()
print(f"Items sorted by their counts: {top_item}\n")
print(f"Most common item and its count: {top_item[0]}\n")
print(f"Most common item's name: {top_item[0][0]}\n")
print(f"Most common item's count: {top_item[0][1]}")
# Out:
# The counter: Counter({'Q': 6, 'U': 5, 'F': 4, 'H': 2, 'W': 2, 'B': 2, 'V': 2, 'I': 2, 'A': 1, 'S': 1, 'G': 1, 'R': 1, 'Y': 1})
#
# Items sorted by their counts: [('Q', 6), ('U', 5), ('F', 4), ('H', 2), ('W', 2), ('B', 2), ('V', 2), ('I', 2), ('A', 1), ('S', 1), ('G', 1), ('R', 1), ('Y', 1)]
#
# Most common item and its count: ('Q', 6)
#
# Most common item's name: Q
#
# Most common item's count: 6

# %%
# Complete the function below.
# The first part checks to make sure k is a valid value,
# based on the data the function is passed.


def classify(neighbours_list, k):
    """
    Inputs:
        neighbours_list : a list of ((lon, lat), label, distance)
        k : the number of neighbours to use for classification
    Returns:
        label : the most commonly observed label of the top k items in neighbours
    """
    if k <= 0:
        raise ValueError("k too low: must be > 0")
    if k > len(neighbours_list):
        raise ValueError("k too high: must be <= the number of neighbours")

    # Your code here...
    top_k = neighbours_list[:k]
    labels = [label for _, label, _ in top_k]
    label_counts = Counter(labels)
    most_common_label = label_counts.most_common(1)[0][0]
    return most_common_label

# %% [markdown]
# ## Testing

# %%
known = [(0, 0, "A"), (1, 1, "A"), (3, 4, "B"), (5, 4, "B"), (1.5, 1.5, "C")]
new = (0.5, 0.5)

neighbours_euc = get_neighbours(new, known, euclidean_distance)
assert classify(neighbours_euc, 3) == "A"

neighbours_man = get_neighbours(new, known, manhattan_distance)
assert classify(neighbours_man, 3) == "A"

print("All good!")
# Out:
# All good!

# %% [markdown]
# ## Putting it all together
#
# Putting this all together, we can now do KNN classification with the following workflow.
#
# (It's not as elegant as `sklearn` but it works!)

# %%
train_data = [(1, 1, "A"), (1, 1.5, "A"), (2, 2, "A"), (4, 5, "B"), (8, 4, "B")]

new_data = [(0.5, 0.5), (9.3, 9.0), (5.1, 5.6)]

for point in new_data:
    neighbours = get_neighbours(point, train_data, euclidean_distance)
    label = classify(neighbours, k=3)

    print(f"Item: {point} Prediction: {label}")
# Out:
# Item: (0.5, 0.5) Prediction: A
# Item: (9.3, 9.0) Prediction: B
# Item: (5.1, 5.6) Prediction: B

# %% [markdown]
# ## KNN: assigning towns to regions
#
# Imagine you are a government official, in charge of assigning new towns to a region.
#
# This job was easy until someone lost all the boundary maps. Now, nobody knows what the geographical properties of each region actually are.
#
# Fortunately, you **do** know which region all the existing towns are in, as well as the coordinates of all those towns.
#
# You decide that the best approach is assign new towns to a region based on which other towns it is nearest to.

# %%
import pandas as pd

data = pd.read_csv("data/uk-towns-sample.csv")

train_data = data[data["kind"] == "Train"]
test_data = data[data["kind"] == "Test"]

train_data.head()
# Out:
#            name          region      lon       lat   kind
# 0  Aaron's Hill          Surrey -0.63098  51.18291  Train
# 1   Abbas Combe        Somerset -2.41825  51.00283  Train
# 2      Abberley  Worcestershire -2.37574  52.30522  Train
# 3      Abberton           Essex  0.91066  51.83440  Train
# 4      Abberton  Worcestershire -2.00817  52.17955  Train

# %%
# Get the data into the expected format for our functions

train_data = list(
    zip(train_data.lon.tolist(), train_data.lat.tolist(), train_data.region.tolist())
)
test_data = list(
    zip(test_data.lon.tolist(), test_data.lat.tolist(), test_data.region.tolist())
)

# %% [markdown]
# With your KNN functions, write a loop that goes through the first 3 items of `test_data` and predicts a region for them.
#
# Get predictions for Euclidean distance, at `k=3` and `k=300`.
#
# What do you observe? What happens when `k` is large? Why do you think that is?

# %%
# Your code here...
for point in test_data:
    neighbours = get_neighbours(point, train_data, euclidean_distance)
    label = classify(neighbours, k=3)

    print(f"Item: {point} Prediction: {label}")
# Out:
# Item: (-1.52539, 53.32291, 'South Yorkshire') Prediction: South Yorkshire
# Item: (-2.89607, 51.96946, 'Herefordshire') Prediction: Herefordshire
# Item: (-2.59953, 50.66559, 'Dorset') Prediction: Dorset
# Item: (-2.16338, 52.14157, 'Worcestershire') Prediction: Worcestershire
# Item: (-4.2282, 52.25011, 'Dyfed') Prediction: Dyfed
# Item: (-3.13475, 51.64734, 'Gwent') Prediction: Gwent
# Item: (-2.7789900000000003, 56.21573000000001, 'Fife') Prediction: Fife
# Item: (-3.34692, 52.11716, 'Powys') Prediction: Powys
# Item: (-4.015219999999999, 53.23395, 'Gwynedd') Prediction: Gwynedd
# Item: (-3.37364, 52.521330000000006, 'Powys') Prediction: Powys
# Item: (-3.38141, 51.749, 'Mid Glamorgan') Prediction: Mid Glamorgan
# Item: (-3.43601, 51.71925, 'Mid Glamorgan') Prediction: Mid Glamorgan
# Item: (-3.64999, 56.31966, 'Perth and Kinross') Prediction: Perth and Kinross
# Item: (-4.08367, 52.41499, 'Dyfed') Prediction: Dyfed
# Item: (-6.99368, 57.96225, 'Western Isles') Prediction: Western Isles
# Item: (-1.97697, 53.05089, 'Staffordshire') Prediction: Staffordshire
# Item: (-3.9486, 55.957980000000006, 'Dunbartonshire') Prediction: Stirling and Falkirk
# Item: (-5.95504, 56.78124, 'Inverness') Prediction: Inverness
# Item: (-2.36424, 53.75275, 'Lancashire') Prediction: Lancashire
# Item: (-5.12175, 56.8049, 'Inverness') Prediction: Inverness
# Item: (-4.187, 58.46008000000001, 'Sutherland') Prediction: Sutherland
# Item: (-5.3144, 57.99451, 'Ross and Cromarty') Prediction: Ross and Cromarty
# Item: (-4.90541, 58.30413000000001, 'Sutherland') Prediction: Sutherland
# Item: (-3.70393, 57.32648, 'Inverness') Prediction: Inverness
# Item: (-5.33409, 57.47974, 'Ross and Cromarty') Prediction: Ross and Cromarty
# Item: (-4.52963, 57.60086999999999, 'Ross and Cromarty') Prediction: Ross and Cromarty
# Item: (-3.11332, 58.4601, 'Caithness') Prediction: Caithness
# Item: (-1.37256, 53.1017, 'Derbyshire') Prediction: Derbyshire
# Item: (1.13618, 51.13863, 'Kent') Prediction: Kent
# Item: (-2.22978, 52.30458, 'Worcestershire') Prediction: Worcestershire
# Item: (-6.23146, 58.48978, 'Western Isles') Prediction: Western Isles
# Item: (-3.16602, 51.48143, 'South Glamorgan') Prediction: Gwent
# Item: (-1.88276, 53.944, 'West Yorkshire') Prediction: West Yorkshire
# Item: (-0.9201, 51.95081, 'Buckinghamshire') Prediction: Buckinghamshire
# Item: (-1.59021, 53.85388, 'West Yorkshire') Prediction: West Yorkshire
# Item: (-3.4610000000000003, 57.389, 'Inverness') Prediction: Banffshire
# Item: (-3.55435, 55.16528, 'Dumfries') Prediction: Dumfries
# Item: (-6.294, 54.50899999999999, 'County Down') Prediction: County Antrim
# Item: (-7.2697600000000016, 57.64676, 'Western Isles') Prediction: Western Isles
# Item: (-6.27963, 58.20924, 'Western Isles') Prediction: Western Isles
# Item: (-2.94145, 58.80353, 'Orkney') Prediction: Caithness
# Item: (-4.97039, 54.89953000000001, 'Wigtown') Prediction: Wigtown
# Item: (-0.62043, 54.47298000000001, 'North Yorkshire') Prediction: North Yorkshire
# Item: (0.1026, 51.4264, 'Greater London') Prediction: Greater London
# Item: (-4.39879, 57.58215, 'Ross and Cromarty') Prediction: Ross and Cromarty
# Item: (0.10132, 51.58297, 'Greater London') Prediction: Greater London
# Item: (-3.77252, 51.21547, 'Devon') Prediction: Devon
# Item: (1.14599, 52.72394, 'Norfolk') Prediction: Norfolk
# Item: (-1.13788, 51.40115, 'Berkshire') Prediction: Berkshire
# Item: (-1.66385, 52.13649, 'Warwickshire') Prediction: Warwickshire
# Item: (-0.76169, 51.24989, 'Hampshire') Prediction: Surrey
# Item: (-0.0777, 51.5132, 'Greater London') Prediction: Greater London
# Item: (0.97133, 52.06328, 'Suffolk') Prediction: Essex
# Item: (-1.88767, 57.44868, 'Aberdeenshire') Prediction: Aberdeenshire
# Item: (-0.52341, 52.42577, 'Northamptonshire') Prediction: Northamptonshire
# Item: (-2.08217, 52.35054, 'Worcestershire') Prediction: Worcestershire
# Item: (-1.45038, 52.08264000000001, 'Oxfordshire') Prediction: Warwickshire
# Item: (-2.8046900000000003, 55.68234, 'Roxburgh, Ettrick and Lauderdale') Prediction: Roxburgh, Ettrick and Lauderdale
# Item: (-2.29744, 56.86253000000001, 'Kincardineshire') Prediction: Kincardineshire
# Item: (-3.41693, 54.74225, 'Cumbria') Prediction: Cumbria
# Item: (-3.34862, 50.74299, 'Devon') Prediction: Devon
# Item: (-3.5809599999999997, 50.52069, 'Devon') Prediction: Devon
# Item: (-0.7929999999999999, 52.59547, 'Leicestershire') Prediction: Rutland
# Item: (-2.15516, 51.47689, 'Wiltshire') Prediction: Wiltshire
# Item: (-3.09215, 53.17887, 'Clwyd') Prediction: Clwyd
# Item: (-5.4840300000000015, 57.31118000000001, 'Ross and Cromarty') Prediction: Ross and Cromarty
# Item: (-4.55811, 57.23648000000001, 'Inverness') Prediction: Inverness
# Item: (1.00911, 52.31101, 'Suffolk') Prediction: Norfolk
# Item: (-3.5165900000000003, 56.419619999999995, 'Perth and Kinross') Prediction: Perth and Kinross
# Item: (-1.70563, 55.41161999999999, 'Northumberland') Prediction: Northumberland
# Item: (-4.51222, 50.60408, 'Cornwall') Prediction: Cornwall
# Item: (-2.08507, 53.51409, 'Greater Manchester') Prediction: Greater Manchester
# Item: (-1.43613, 53.70783, 'West Yorkshire') Prediction: West Yorkshire
# Item: (-1.54086, 53.85169000000001, 'West Yorkshire') Prediction: West Yorkshire
# Item: (-0.78752, 51.4125, 'Berkshire') Prediction: Berkshire
# Item: (-2.90156, 50.84928, 'Somerset') Prediction: Somerset
# Item: (-0.46369, 51.00778, 'West Sussex') Prediction: West Sussex
# Item: (0.58399, 52.83465, 'Norfolk') Prediction: Norfolk
# Item: (-6.1958, 54.3008, 'County Down') Prediction: County Down
# Item: (-5.18032, 56.350669999999994, 'Argyll and Bute') Prediction: Argyll and Bute
# Item: (-5.52491, 57.5292, 'Ross and Cromarty') Prediction: Ross and Cromarty
# Item: (-1.23378, 53.07565, 'Nottinghamshire') Prediction: Nottinghamshire
# Item: (1.55482, 52.245709999999995, 'Suffolk') Prediction: Suffolk
# Item: (-1.70934, 52.822419999999994, 'Staffordshire') Prediction: Staffordshire
# Item: (-2.33779, 50.825109999999995, 'Dorset') Prediction: Dorset
# Item: (-4.25125, 50.36864, 'Cornwall') Prediction: Cornwall
# Item: (-4.23257, 50.39494000000001, 'Cornwall') Prediction: Cornwall
# Item: (-1.50559, 51.3875, 'Berkshire') Prediction: Berkshire
# Item: (0.043, 51.30778, 'Greater London') Prediction: Greater London
# Item: (-2.22002, 54.31138000000001, 'North Yorkshire') Prediction: North Yorkshire
# Item: (-5.8131699999999995, 57.433609999999994, 'Ross and Cromarty') Prediction: Ross and Cromarty
# Item: (0.78232, 51.04587, 'Kent') Prediction: Kent
# Item: (-2.7629900000000003, 55.44879, 'Roxburgh, Ettrick and Lauderdale') Prediction: Roxburgh, Ettrick and Lauderdale
# Item: (-2.32476, 53.15279, 'Cheshire') Prediction: Cheshire
# Item: (-5.2958099999999995, 56.46229, 'Argyll and Bute') Prediction: Argyll and Bute
# Item: (-4.16448, 56.49516, 'Stirling and Falkirk') Prediction: Perth and Kinross
# Item: (-5.28375, 57.85406999999999, 'Ross and Cromarty') Prediction: Ross and Cromarty
# Item: (-5.62477, 56.24283000000001, 'Argyll and Bute') Prediction: Argyll and Bute
# Item: (-5.10168, 57.8434, 'Ross and Cromarty') Prediction: Ross and Cromarty
# Item: (-6.66245, 58.06239, 'Western Isles') Prediction: Western Isles
# Item: (-2.49559, 53.32415, 'Cheshire') Prediction: Cheshire
# Item: (-3.97713, 51.15844, 'Devon') Prediction: Devon
# Item: (-2.35071, 52.88943, 'Staffordshire') Prediction: Staffordshire
# Item: (-0.4408899999999999, 52.460919999999994, 'Northamptonshire') Prediction: Northamptonshire
# Item: (-2.0402400000000003, 50.69277, 'Dorset') Prediction: Dorset
# Item: (-1.23665, 50.67307, 'Isle of Wight') Prediction: Isle of Wight
# Item: (-1.79185, 53.55454, 'West Yorkshire') Prediction: West Yorkshire
# Item: (-1.42559, 53.83375, 'West Yorkshire') Prediction: West Yorkshire
# Item: (-3.45315, 54.56948000000001, 'Cumbria') Prediction: Cumbria
# Item: (-0.72559, 51.24566, 'Surrey') Prediction: Surrey
# Item: (1.18725, 52.13957, 'Suffolk') Prediction: Suffolk
# Item: (-3.755630000000002, 50.51562, 'Devon') Prediction: Devon
# Item: (-1.16218, 52.30832, 'Northamptonshire') Prediction: Northamptonshire
# Item: (0.31317, 52.05492, 'Essex') Prediction: Essex
# Item: (0.85201, 51.67669, 'Essex') Prediction: Essex
# Item: (-1.23223, 51.26208, 'Hampshire') Prediction: Hampshire
# Item: (-3.95884, 56.2126, 'Stirling and Falkirk') Prediction: Stirling and Falkirk
# Item: (1.31471, 52.31405, 'Suffolk') Prediction: Suffolk
# Item: (0.8710899999999999, 51.14844, 'Kent') Prediction: Kent
# Item: (-0.46206, 51.43287, 'Surrey') Prediction: Surrey
# Item: (-0.39002, 50.93325, 'West Sussex') Prediction: West Sussex
# Item: (-2.27454, 51.92844, 'Gloucestershire') Prediction: Gloucestershire
# Item: (-1.80517, 50.83888, 'Dorset') Prediction: Dorset
# Item: (-2.34554, 53.37106, 'Greater Manchester') Prediction: Greater Manchester
# Item: (-2.7721400000000003, 52.30173, 'Herefordshire') Prediction: Herefordshire
# Item: (-0.4193199999999999, 51.3793, 'Surrey') Prediction: Surrey
# Item: (-2.33893, 51.69737, 'Gloucestershire') Prediction: Gloucestershire
# Item: (-1.46687, 53.1433, 'Derbyshire') Prediction: Derbyshire
# Item: (-1.5452, 52.33037, 'Warwickshire') Prediction: Warwickshire
# Item: (-0.44681, 52.48239, 'Northamptonshire') Prediction: Northamptonshire
# Item: (-2.20127, 52.49115, 'Staffordshire') Prediction: West Midlands
# Item: (-1.74394, 53.9303, 'North Yorkshire') Prediction: West Yorkshire
# Item: (1.1711, 52.23924, 'Suffolk') Prediction: Suffolk
# Item: (-2.23234, 53.15104, 'Cheshire') Prediction: Cheshire
# Item: (-2.43151, 53.60418000000001, 'Greater Manchester') Prediction: Greater Manchester
# Item: (-1.50814, 51.7248, 'Oxfordshire') Prediction: Oxfordshire
# Item: (-2.52135, 53.10718000000001, 'Cheshire') Prediction: Cheshire
# Item: (-1.27735, 52.15303, 'Northamptonshire') Prediction: Northamptonshire
# Item: (-2.0873, 52.0094, 'Gloucestershire') Prediction: Gloucestershire
# Item: (-0.90447, 51.76384, 'Buckinghamshire') Prediction: Buckinghamshire
# Item: (-2.32823, 50.74678, 'Dorset') Prediction: Dorset
# Item: (-0.57876, 50.80229, 'West Sussex') Prediction: West Sussex
# Item: (-1.70195, 52.15678, 'Warwickshire') Prediction: Warwickshire
# Item: (-1.65687, 53.03676, 'Derbyshire') Prediction: Derbyshire
# Item: (-5.24087, 55.90289, 'Argyll and Bute') Prediction: Argyll and Bute
# Item: (-2.65175, 57.52666, 'Banffshire') Prediction: Banffshire
# Item: (-3.26685, 56.150319999999994, 'Fife') Prediction: Fife
# Item: (-2.12449, 53.47211, 'Greater Manchester') Prediction: Greater Manchester
# Item: (-2.50795, 52.98885, 'Cheshire') Prediction: Cheshire
# Item: (-2.09012, 54.63594000000001, 'Durham') Prediction: North Yorkshire
# Item: (-4.03749, 58.583009999999994, 'Sutherland') Prediction: Sutherland
# Item: (-0.44818, 52.93674, 'Lincolnshire') Prediction: Lincolnshire
# Item: (-0.07484, 52.77783, 'Lincolnshire') Prediction: Lincolnshire
# Item: (-1.4403, 53.799119999999995, 'West Yorkshire') Prediction: West Yorkshire
# Item: (-1.85514, 51.42837, 'Wiltshire') Prediction: Wiltshire
# Item: (0.08056, 51.45026, 'Greater London') Prediction: Greater London
# Item: (-2.06033, 51.48859, 'Wiltshire') Prediction: Wiltshire
# Item: (-1.80614, 50.83179000000001, 'Dorset') Prediction: Dorset
# Item: (-1.40248, 52.14643, 'Warwickshire') Prediction: Warwickshire
# Item: (-2.81739, 51.28723, 'Somerset') Prediction: Somerset
# Item: (-1.12903, 51.18651, 'Hampshire') Prediction: Hampshire
# Item: (-1.56175, 54.59904, 'Durham') Prediction: Durham
# Item: (-3.3628099999999996, 50.71737, 'Devon') Prediction: Devon
# Item: (-2.49878, 52.03703, 'Herefordshire') Prediction: Herefordshire

# %% [markdown]
# ## Evaluating the predictions
#
# The cell below will use the test data to evaluate performance at different `k` values. As you can see, setting `k` too high or too low hurts performance on unseen data.
#
# Note that our implementation takes around 1 second to run all these predictions.

# %%
# %%time

from sklearn.metrics import f1_score

for k in [1, 3, 5, 10, 20, 100, 300]:
    predictions = []
    expected = []

    for lon, lat, region in test_data:
        point = (lon, lat)

        neighbours = get_neighbours(point, train_data, euclidean_distance)
        label = classify(neighbours, k=k)

        predictions.append(label)
        expected.append(region)

    print(
        f'F1 score for k={k}\t: {f1_score(expected, predictions, zero_division=0, average="weighted"):.3f}'
    )
# Out:
# F1 score for k=1	: 0.898
# F1 score for k=3	: 0.912
# F1 score for k=5	: 0.891
# F1 score for k=10	: 0.846
# F1 score for k=20	: 0.772
# F1 score for k=100	: 0.382
# F1 score for k=300	: 0.095
# CPU times: user 1.71 s, sys: 244 ms, total: 1.96 s
# Wall time: 2.48 s

# %% [markdown]
# ## Recreating the map
#
# How could you use the data and the model to create a new map, showing the regional boundaries? How would it compare to the "true" map?

# %%
# Your thoughts below...

# %% [markdown]
# Running the cell below will do the following
#
# 1. Determine the min/max lon/lat points
# 2. Use these to create a grid of (x,y) points
# 3. Classify all these points using the KNN model
# 4. Colour each point according to prediction
# 5. Plot predictions and towns
#
# (It will take maybe a minute or two, because the KNN prediction process is not optimised! But there is a little progress bar, to show you that things are happening.)

# %%
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
from tqdm.notebook import tqdm

colour_vals = np.linspace(0, 1, 96)
np.random.seed(5)
np.random.shuffle(colour_vals)
cmap = plt.cm.colors.ListedColormap(plt.cm.hsv(colour_vals))


def plot(k):
    # Make coords for predicting
    min_lon, max_lon = (
        min(train_data, key=itemgetter(0))[0],
        max(train_data, key=itemgetter(0))[0],
    )
    min_lat, max_lat = (
        min(train_data, key=itemgetter(1))[1],
        max(train_data, key=itemgetter(1))[1],
    )

    xx, yy = np.meshgrid(
        np.arange(min_lon, max_lon, 0.1), np.arange(min_lat, max_lat, 0.1)
    )

    # Do the predictions
    grid_predictions = []
    for point in tqdm(zip(xx.flatten(), yy.flatten()), total=len(xx.flatten())):
        neighbours = get_neighbours(point, train_data, euclidean_distance)
        label = classify(neighbours, k=k)
        grid_predictions.append(label)
    grid_predictions = np.array(grid_predictions).reshape(xx.shape)

    # Need to be able to convert between text and numerical labels, to plot properly
    p_to_i = {p: i for i, p in enumerate(set([i[2] for i in train_data]))}
    i_to_p = {i: p for i, p in enumerate(set([i[2] for i in train_data]))}

    # Plot each grid prediction
    plt.pcolormesh(
        xx,
        yy,
        np.array([p_to_i[p] for p in grid_predictions.flatten()]).reshape(xx.shape),
        cmap=cmap,
        shading="auto",
    )

    # Plot the towns, coloured by region
    x_vals = [i[0] for i in train_data]
    y_vals = [i[1] for i in train_data]
    colors = [p_to_i[i[2]] for i in train_data]
    plt.scatter(x_vals, y_vals, c=colors, cmap=cmap, edgecolor="k", s=30)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title(f"k={k}")

    # Output a classification report


f, a = plt.subplots(1, 3, figsize=(36, 18))

for i, k in enumerate([5, 10, 20]):
    plt.sca(a[i])
    plot(k)
# Out:
#   0%|          | 0/9765 [00:00<?, ?it/s]
#   0%|          | 0/9765 [00:00<?, ?it/s]
#   0%|          | 0/9765 [00:00<?, ?it/s]

# %% [markdown]
# ## Interpreting the boundaries
#
# In the three plots, we used a `k` of 3, 10 and 20. What do you observe in terms of the decision boundaries?
#
# What problems do you anticipate in terms of using this as a map of the country's regional boundaries?

# %%
# Your thoughts below...

# %% [markdown]
# # KNN: sklearn
#
# Now let's compare our implementation to that in `sklearn`. Run the cell below. You'll see it only takes 100ms, compared to 1s for ours!

# %%
# %%time

from sklearn.neighbors import KNeighborsClassifier

data = pd.read_csv("data/uk-towns-sample.csv")

train_data = data[data.kind == "Train"]
test_data = data[data.kind == "Test"]

for our_score, k in zip(
    [0.898, 0.912, 0.891, 0.846, 0.772, 0.382, 0.095], [1, 3, 5, 10, 20, 100, 300]
):
    knn = KNeighborsClassifier(n_neighbors=k)

    knn.fit(train_data[["lon", "lat"]], train_data["region"])
    sklearn_score = knn.score(test_data[["lon", "lat"]], test_data["region"])

    print(f"k={k}")
    print(f"sklearn F1 score: {sklearn_score:.3f}")
    print(f"Our F1 score: {our_score}")
    if our_score - sklearn_score > 0:
        print(f"Ours was better by {our_score - sklearn_score:.3f}\n\n")
    else:
        print(f"Sklearn was better by {our_score - sklearn_score:.3f}\n\n")
# Out:
# k=1
# sklearn F1 score: 0.896
# Our F1 score: 0.898
# Ours was better by 0.002
#
#
# k=3
# sklearn F1 score: 0.909
# Our F1 score: 0.912
# Ours was better by 0.003
#
#
# k=5
# sklearn F1 score: 0.878
# Our F1 score: 0.891
# Ours was better by 0.013
#
#
# k=10
# sklearn F1 score: 0.848
# Our F1 score: 0.846
# Sklearn was better by -0.002
#
#
# k=20
# sklearn F1 score: 0.768
# Our F1 score: 0.772
# Ours was better by 0.004
#
#
# k=100
# sklearn F1 score: 0.445
# Our F1 score: 0.382
# Sklearn was better by -0.063
#
#
# k=300
# sklearn F1 score: 0.177
# Our F1 score: 0.095
# Sklearn was better by -0.082
#
#
# CPU times: user 184 ms, sys: 60.9 ms, total: 245 ms
# Wall time: 500 ms

# %% [markdown]
# # Conclusion
#
# In this practical, you implemented and explored supervised algorithms for discriminative classification. You implemented k-nearest neighbours yourself, but also used `sklearn`'s (much faster) version of it.
#
# If you want to extend the work here, you could explore how the different distance measures impacts KNN performance - can you generate a better boundary map?
